# %% [markdown]
# ### **<center><span style="color:#FF00D4">Entrainement Python</span><center>**

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
print(os.getcwd())
print(os.listdir())

a = np.loadtxt("sismique.txt")

a_v = a*10**-6
dt = 2

N = len(a_v)
t = np.linspace(0,N*dt,N)

plt.plot(t,a_v)
plt.title("Trace Sismique", color="red")
plt.xlabel("Temps [ms]")
plt.ylabel("Amplitude [V]")
plt.grid(True)
plt.show()
# Out:
# /home/matteo/Outils_Numeriques
# ['testnaval.py', 'Miniprojet.ipynb', 'sismique.txt', 'TP2.ipynb', 'testgeopandas.ipynb', '.git', 'rock_properties_TP4.xlsx', 'Exercice.ipynb', 'bataille_navale', 'TP4.ipynb', 'TP3.ipynb', 'Fonctions.py', 'TP1.ipynb', '.venv', 'Entrainement.ipynb', 'Enoncés_TD']
